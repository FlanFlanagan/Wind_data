# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
from math import sin
import random

# %%
values = []
i = 0
while i < 100:
    values.append(10+5*math.sin(i/25)*random.random())
    i+=1

# %%
a_x = 4
m_x = 1
model = sm.tsa.ARMA(values, (a_x, m_x)).fit()
l = len(model.params)
x = []
for v in model.params:
    x.append(v)
m = x[0]
a = x[1:a_x+1]
mr = x[a_x+1:]
print(m, a, mr)
# Out:
# 10.190800890757645 [0.7137013918346503, 0.13067854737022064, 0.13231130734652546, -0.0007496379683328336] [-0.6185014688055507]

# %%
hist = sm.tsa.arma_generate_sample(ar = x,
                                   ma = y,
                                   nsample = 100,
                                   burnin = 0)

# %%
hist=m*hist

# %%
plt.plot(hist)

# %%
plt.plot(time, values)
